# %% [markdown]
# # BME 1132 Probability and Biostatistics
# ## ASSIGNMENT

# %% [markdown]
# _Write appropriate scripts in R to solve the following Questions. (You can write either __Python__ or __Matlab__, but to do this you have to need some modifications on the codes.) To solve them you may need to do some additional programming researches and studies. Show your references as a footnote where necessary. You have to collaborate with one of your friend and you should __write__ your __report as a team__ (Teams will consist __exactly two__ students.) Any __cheating, copy-paste, etc.__ will result in __zero grade__ for students who are involved. Your report should include your code, your results (images, graphs, text, etc.), as well as your comments about your code and your results. The deadline for the report is __23$^{th}$ March 2020__. You are requested to bring a printed out copy of your report the day when you are coming to __Midterm I.__ Any late assignments will not be evaluated. <br> <br>
# Good luck._

# %% [markdown]
# ### Name:
# ### Surname:
# ### Student ID: <br> <br>
# ### Name:
# ### Surname:
# ### Student ID:

# %% [markdown]
# __Peripheral neuropathy__ is a complication of diabetes mellitus
# in which peripheral nerves are damaged, leading to
# many symptoms, including spasms, tingling, numbness
# and pain.

# %% [markdown]
# ![peripheral-neuropathy.jpg](attachment:peripheral-neuropathy.jpg)

# %% [markdown]
# The pain scores for the people treated with the cannabis
# medicinal in a study are;

# %%
pain_scores = c(90, 10, 45, 70, 13, 27, 11, 70, 14, 15, 13, 75, 50, 30,
80, 40, 29, 13, 9, 7, 20, 85, 55, 94)

# %% [markdown]
# __Question 1__ <br> In the first step find the mean,
# median, standard deviation, and 25th and 75th percentiles using with build-in R functions. In second step create/ write your own functions which calculate the values in first step and print the results on screen only two digits. <br> __NOTE 1:__ In your own fuctions, you can use other built-in R functions, unfortunately you should not use direct __mean()__, __median()__... functions.

# %% [markdown]
# __NOTE2 :__ _Function Definition_
#
# An R function is created by using the keyword __function()__. The basic syntax of an R function definition is as follows;

# %% [raw]
# function_name <- function(arg_1, arg_2, ...) {
#    Function body
# }

# %%
ortalama <- function(a) {
    b <- round(sum(a) / length(a), digits=2)
    print(b)
}

# %%
mean(pain_scores)
# Out:
# [1] 40.20833

# %%
ortalama(pain_scores)
# Out:
# [1] 40.21

# %% [markdown]
# __Question 2__ <br> Figure the histogram, stem-and-leaf plot and boxplot for the pain scores data.
# Print all the figures side by side (subplot). <br> __NOTE3 :__ You can use __par()__ function for this purpose.

# %%
par(mfrow=c(1,3))
boxplot(pain_scores, col="yellow")
hist(pain_scores, col="blue")
plot.new()
tmp <- capture.output(stem(pain_scores))
text(0, 1, paste(tmp, collapse='\n'), adj=c(0,1), family='mono', cex=1.2) #you can adjust the size of the text using cex parameter
# Out:
# Plot with title "Histogram of pain_scores"

# %% [markdown]
# __Question 3__ <br>  Create a frequency distribution for the following 1000 birthweights' data set.

# %%
install.packages("readxl")
# Out:
# Warning message:
# "unable to access index for repository https://cran.r-project.org/src/contrib:
#   URL 'https://cran.r-project.org/src/contrib/PACKAGES' açılamıyor"Warning message:
# "package 'readxl' is not available (for R version 3.6.0)"Warning message:
# "unable to access index for repository https://cran.r-project.org/bin/windows/contrib/3.6:
#   URL 'https://cran.r-project.org/bin/windows/contrib/3.6/PACKAGES' açılamıyor"

# %%
library('readxl')
# Out:
# Warning message:
# "package 'readxl' was built under R version 3.6.3"

# %%
weights <- read_excel("C:/Users/aliaj/Desktop/2019 Spring_BME1132_Probability and Biostatistics/Assignment/weights_gr.xlsx")

# %% [markdown]
# __Step 1:__ Number of classes.

# %% [markdown]
# \begin{equation*}
# 2^k > n
# \end{equation*}

# %%
log(1000)/log(2)
# Out:
# [1] 9.965784

# %% [markdown]
# k = 10

# %% [markdown]
# You will find the results of the following steps and print the outputs to screen as a table. <br> <br>
# __Step 2:__ Class widths. <br> __Step 3:__ Class limits. <br> __Step 4:__ Tally the observation into the classes. <br> __Step 5:__ Count the number of items in each class.

# %% [markdown]
# __Question 4__ <br>  Calculate the mean, median, variance and standard deviation using the formulas which you have learnt in the lecture for the frequency distribution in Question 3.

# %% [markdown]
# __Question 5__ <br>  Find the mean, median, variance and standard deviation using the R built-in functions for the 1000 birthweights raw data and compare your results with Question 4.
